# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
iris = datasets.load_iris()

# Convert to a DataFrame
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target

# Filter for binary classification 'versicolor' vs 'virginica' ['setosa' 'versicolor' 'virginica']
X = iris_df[iris_df['species'].isin([1, 2])].copy()

# Relabel the target column (optional: make species binary 0 and 1)
X['species'] = X['species'].map({1: 0, 2: 1})

#to array
X = X.values

# Print the filtered dataset
X.shape # (100, 5)
# Out:
# (100, 5)

# %%
#train test split
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)
y_train = X_train[:, -1].reshape(-1, 1)
y_test = X_test[:, -1].reshape(-1, 1)
X_train = X_train[:, :-1]
X_test = X_test[:, :-1]

print(X_train.shape) # (80, 5) m examples, n features
print(X_test.shape)  # (20, 5)
print(y_train.shape) # (80,1)
print(y_test.shape)  # (20,1)

X_train = X_train.T
X_test = X_test.T
y_train = y_train.T
y_test = y_test.T
# Out:
# (80, 4)
# (20, 4)
# (80, 1)
# (20, 1)

# %%
#Logistic Regression
from models.logisticregression import LogisticRegression
from models.gradient_check import gradient_check

lr_model = LogisticRegression(n_inputs=X_train.shape[0], lambd_reg=0.01)
lr_model.fit(X_train, y_train, learning_rate=0.01, n_iters=10000)
predictions = lr_model.predict(X_test)

accuracy = np.mean(predictions == y_test)
print(f'Accuracy: {accuracy}')
# Out:
# Cost after iteration 0: 4.464423400572354
# Cost after iteration 100: 0.5677639597116839
# Cost after iteration 200: 0.5372020782531204
# Cost after iteration 300: 0.5097677684246726
# Cost after iteration 400: 0.4850760988438422
# Cost after iteration 500: 0.46278836422610536
# Cost after iteration 600: 0.44260887662494613
# Cost after iteration 700: 0.4242808292625258
# Cost after iteration 800: 0.4075818609934721
# Cost after iteration 900: 0.3923197094660257
# Cost after iteration 1000: 0.37832816889600884
# Cost after iteration 1100: 0.3654634537674616
# Cost after iteration 1200: 0.35360099843395953
# Cost after iteration 1300: 0.34263268132062524
# Cost after iteration 1400: 0.3324644408436957
# Cost after iteration 1500: 0.3230142408227515
# Cost after iteration 1600: 0.31421034102645845
# Cost after iteration 1700: 0.30598983031841304
# Cost after iteration 1800: 0.2982973836436536
# Cost after iteration 1900: 0.291084208623191
# Cost after iteration 2000: 0.2843071521282195
# Cost after iteration 2100: 0.2779279415333496
# Cost after iteration 2200: 0.2719125392369639
# Cost after iteration 2300: 0.26623059243471103
# Cost after iteration 2400: 0.26085496304740374
# Cost after iteration 2500: 0.25576132517538847
# Cost after iteration 2600: 0.25092781952843984
# Cost after iteration 2700: 0.2463347560167287
# Cost after iteration 2800: 0.24196435713523534
# Cost after iteration 2900: 0.2378005359769977
# Cost after iteration 3000: 0.23382870370997294
# Cost after iteration 3100: 0.23003560218237287
# Cost after iteration 3200: 0.22640915801113115
# Cost after iteration 3300: 0.2229383550819138
# Cost after iteration 3400: 0.21961312286692689
# Cost after iteration 3500: 0.21642423836537503
# Cost after iteration 3600: 0.21336323980449168
# Cost after iteration 3700: 0.21042235051792876
# Cost after iteration 3800: 0.2075944116522339
# Cost after iteration 3900: 0.2048728225488291
# Cost after iteration 4000: 0.20225148781462052
# Cost after iteration 4100: 0.19972477023430155
# Cost after iteration 4200: 0.19728744879583715
# Cost after iteration 4300: 0.19493468120107088
# Cost after iteration 4400: 0.19266197031878873
# Cost after iteration 4500: 0.19046513411033222
# Cost after iteration 4600: 0.18834027861997865
# Cost after iteration 4700: 0.18628377367547522
# Cost after iteration 4800: 0.1842922309897086
# Cost after iteration 4900: 0.18236248439368097
# Cost after iteration 5000: 0.18049157196471363
# Cost after iteration 5100: 0.178676719842929
# Cost after iteration 5200: 0.17691532755425313
# Cost after iteration 5300: 0.17520495468000416
# Cost after iteration 5400: 0.1735433087320892
# Cost after iteration 5500: 0.1719282341093132
# Cost after iteration 5600: 0.17035770202467007
# Cost after iteration 5700: 0.16882980130603478
# Cost after iteration 5800: 0.16734272998364116
# Cost after iteration 5900: 0.16589478758734905
# Cost after iteration 6000: 0.16448436808514222
# Cost after iteration 6100: 0.1631099534017163
# Cost after iteration 6200: 0.16177010746255321
# Cost after iteration 6300: 0.1604634707146412
# Cost after iteration 6400: 0.15918875508009392
# Cost after iteration 6500: 0.1579447393034264
# Cost after iteration 6600: 0.15673026465724244
# Cost after iteration 6700: 0.1555442309746309
# Cost after iteration 6800: 0.15438559297972038
# Cost after iteration 6900: 0.15325335689064562
# Cost after iteration 7000: 0.15214657727168007
# Cost after iteration 7100: 0.15106435411351873
# Cost after iteration 7200: 0.15000583012269175
# Cost after iteration 7300: 0.14897018820287303
# Cost after iteration 7400: 0.14795664911244696
# Cost after iteration 7500: 0.1469644692841325
# Cost after iteration 7600: 0.14599293879375275
# Cost after iteration 7700: 0.14504137946639628
# Cost after iteration 7800: 0.14410914310926162
# Cost after iteration 7900: 0.1431956098614188
# Cost after iteration 8000: 0.1423001866515658
# Cost after iteration 8100: 0.14142230575563394
# Cost after iteration 8200: 0.140561423446781
# Cost after iteration 8300: 0.1397170187309469
# Cost after iteration 8400: 0.13888859216171157
# Cost after iteration 8500: 0.13807566472871471
# Cost after iteration 8600: 0.13727777681436415
# Cost after iteration 8700: 0.13649448721398919
# Cost after iteration 8800: 0.13572537221497957
# Cost after iteration 8900: 0.13497002473081024
# Cost after iteration 9000: 0.13422805348616892
# Cost after iteration 9100: 0.13349908224970172
# Cost after iteration 9200: 0.13278274911115956
# Cost after iteration 9300: 0.13207870579997447
# Cost after iteration 9400: 0.13138661704251758
# Cost after iteration 9500: 0.13070615995550214
# Cost after iteration 9600: 0.13003702347317553
# Cost after iteration 9700: 0.12937890780612588
# Cost after iteration 9800: 0.12873152392968124
# Cost after iteration 9900: 0.12809459310002852
# Accuracy: 0.85

# %%
from models.fnn_classifier import FNN1Layer
# Train the model
fnn1_model = FNN1Layer(input_dim=X_train.shape[0], output_dim=1, nunits=4, lambd_reg=0.001, dropout=None)
parameters, costs = fnn1_model.fit(X_train, y_train, learning_rate=0.01, n_iters=10000)
predictions = fnn1_model.predict(X_test)

#plot the cost
import matplotlib.pyplot as plt
plt.plot(costs)
plt.xlabel('Iterations')
plt.ylabel('Cost')

accuracy = np.mean(predictions == y_test)
print(f'Accuracy: {accuracy}')
# Out:
# Cost after iteration 0: 0.7129529001752754
# Cost after iteration 100: 0.6927150044561934
# Cost after iteration 200: 0.6905521946740466
# Cost after iteration 300: 0.6894835238624449
# Cost after iteration 400: 0.6866371017383522
# Cost after iteration 500: 0.6717392548704852
# Cost after iteration 600: 0.6540682378193201
# Cost after iteration 700: 0.6362657727696067
# Cost after iteration 800: 0.6141807335342822
# Cost after iteration 900: 0.5871101820493443
# Cost after iteration 1000: 0.5552461352655118
# Cost after iteration 1100: 0.5196017571571093
# Cost after iteration 1200: 0.48179214931637854
# Cost after iteration 1300: 0.44362890655714887
# Cost after iteration 1400: 0.406709133725077
# Cost after iteration 1500: 0.3721694966788397
# Cost after iteration 1600: 0.3406418705829779
# Cost after iteration 1700: 0.3123418312496317
# Cost after iteration 1800: 0.28720200433301574
# Cost after iteration 1900: 0.2649935924334108
# Cost after iteration 2000: 0.24541501724475312
# Cost after iteration 2100: 0.2281477862232259
# Cost after iteration 2200: 0.21288749876088509
# Cost after iteration 2300: 0.1993585385160384
# Cost after iteration 2400: 0.18731909212387718
# Cost after iteration 2500: 0.17656093815917173
# Cost after iteration 2600: 0.16690672022104314
# Cost after iteration 2700: 0.15820624922980767
# Cost after iteration 2800: 0.15033265582786137
# Cost after iteration 2900: 0.1431787909771882
# Cost after iteration 3000: 0.13665403810112006
# Cost after iteration 3100: 0.130681576619594
# Cost after iteration 3200: 0.12519607642504654
# Cost after iteration 3300: 0.12014177711803574
# Cost after iteration 3400: 0.11547089819965205
# Cost after iteration 3500: 0.11114232769748392
# Cost after iteration 3600: 0.10712054188867103
# Cost after iteration 3700: 0.10337471526494241
# Cost after iteration 3800: 0.09987798636716297
# Cost after iteration 3900: 0.09660685102038016
# Cost after iteration 4000: 0.09354065961745472
# Cost after iteration 4100: 0.09066119940890129
# Cost after iteration 4200: 0.08795234632238963
# Cost after iteration 4300: 0.0853997737533291
# Cost after iteration 4400: 0.08299070813942076
# Cost after iteration 4500: 0.08071372305142213
# Cost after iteration 4600: 0.07855856508236696
# Cost after iteration 4700: 0.07651600606801082
# Cost after iteration 4800: 0.07457771718020188
# Cost after iteration 4900: 0.07273616124941702
# Cost after iteration 5000: 0.0709845003310599
# Cost after iteration 5100: 0.06931651606305113
# Cost after iteration 5200: 0.06772654079441397
# Cost after iteration 5300: 0.06620939781572828
# Cost after iteration 5400: 0.06476034930829687
# Cost after iteration 5500: 0.06337505086228781
# Cost after iteration 5600: 0.06204951160511777
# Cost after iteration 5700: 0.060780059138018164
# Cost after iteration 5800: 0.059563308607609076
# Cost after iteration 5900: 0.05839613534560348
# Cost after iteration 6000: 0.057275650597691116
# Cost after iteration 6100: 0.05619917993559095
# Cost after iteration 6200: 0.05516424400694744
# Cost after iteration 6300: 0.05416854132839549
# Cost after iteration 6400: 0.05320993286951567
# Cost after iteration 6500: 0.052286428211001726
# Cost after iteration 6600: 0.05139617309035381
# Cost after iteration 6700: 0.050537438173748624
# Cost after iteration 6800: 0.04970860891422174
# Cost after iteration 6900: 0.048908176374554926
# Cost after iteration 7000: 0.04813472890884574
# Cost after iteration 7100: 0.047386944610058664
# Cost after iteration 7200: 0.04666358444229578
# Cost after iteration 7300: 0.04596348598636943
# Cost after iteration 7400: 0.04528555773575059
# Cost after iteration 7500: 0.044628773887326625
# Cost after iteration 7600: 0.043992169577778684
# Cost after iteration 7700: 0.04337483652195251
# Cost after iteration 7800: 0.042775919014433963
# Cost after iteration 7900: 0.04219461025978926
# Cost after iteration 8000: 0.04163014900064342
# Cost after iteration 8100: 0.04108181641603706
# Cost after iteration 8200: 0.04054893326538383
# Cost after iteration 8300: 0.04003085725588839
# Cost after iteration 8400: 0.039526980613532166
# Cost after iteration 8500: 0.03903672783972836
# Cost after iteration 8600: 0.03855955363751443
# Cost after iteration 8700: 0.03809494099272288
# Cost after iteration 8800: 0.03764239939697741
# Cost after iteration 8900: 0.037201463200608645
# Cost after iteration 9000: 0.03677169008470406
# Cost after iteration 9100: 0.03635265964251196
# Cost after iteration 9200: 0.03594397206131264
# Cost after iteration 9300: 0.035545246896680906
# Cost after iteration 9400: 0.03515612193178849
# Cost after iteration 9500: 0.034776252115048256
# Cost after iteration 9600: 0.03440530856999099
# Cost after iteration 9700: 0.03404297767179902
# Cost after iteration 9800: 0.033688960185398874
# Cost after iteration 9900: 0.03334297046045225
# Accuracy: 0.85

# %%
from models.fnn_classifier import FNNClassifier

fnn_model = FNNClassifier(X_train.shape[0], 1, [2], ["relu"], lamdb_reg=0.001)
fnn_model.initialize_parameters()
gradient_check(fnn_model, X_train, y_train, epsilon=1e-7)
parameters = fnn_model.fit(X_train, y_train, optimizer="adam", learning_rate=0.01, n_iters=10000)
predictions = fnn_model.predict(X_test)

accuracy = np.mean(predictions == y_test)
print(f'Accuracy: {accuracy}')
# Out:
# Backward propagation works well! Difference = 3.0336276628391194e-08
# Cost after iteration 0: 0.6931471857717378
# Cost after iteration 100: 0.6926548722422957
# Cost after iteration 200: 0.6923564371630787
# Cost after iteration 300: 0.6921755061204898
# Cost after iteration 400: 0.6920657970424448
# Cost after iteration 500: 0.6919992639385324
# Cost after iteration 600: 0.6919589093649285
# Cost after iteration 700: 0.6919344300381629
# Cost after iteration 800: 0.6919195792463702
# Cost after iteration 900: 0.6919105690245151
# Cost after iteration 1000: 0.6919051020084387
# Cost after iteration 1100: 0.6919017846797699
# Cost after iteration 1200: 0.6918997716730814
# Cost after iteration 1300: 0.6918985501078667
# Cost after iteration 1400: 0.6918978087980884
# Cost after iteration 1500: 0.6918973589229778
# Cost after iteration 1600: 0.6918970859048903
# Cost after iteration 1700: 0.6918969202147917
# Cost after iteration 1800: 0.6918968196592087
# Cost after iteration 1900: 0.6918967586325757
# Cost after iteration 2000: 0.6918967215955965
# Cost after iteration 2100: 0.691896699117776
# Cost after iteration 2200: 0.6918966854758676
# Cost after iteration 2300: 0.6918966771964769
# Cost after iteration 2400: 0.6918966721716119
# Cost after iteration 2500: 0.6918966691219339
# Cost after iteration 2600: 0.6918966672710082
# Cost after iteration 2700: 0.6918966661476139
# Cost after iteration 2800: 0.6918966654657644
# Cost after iteration 2900: 0.691896665051892
# Cost after iteration 3000: 0.6918966648006575
# Cost after iteration 3100: 0.6918966646481295
# Cost after iteration 3200: 0.6918966645555076
# Cost after iteration 3300: 0.6918966644992431
# Cost after iteration 3400: 0.6918966644650444
# Cost after iteration 3500: 0.6918966644442377
# Cost after iteration 3600: 0.6918966644315587
# Cost after iteration 3700: 0.6918966644238126
# Cost after iteration 3800: 0.6918966644190603
# Cost after iteration 3900: 0.6918966644161246
# Cost after iteration 4000: 0.6918966644142921
# Cost after iteration 4100: 0.6918966644131286
# Cost after iteration 4200: 0.6918966644123713
# Cost after iteration 4300: 0.6918966644118605
# Cost after iteration 4400: 0.6918966644114994
# Cost after iteration 4500: 0.6918966644112289
# Cost after iteration 4600: 0.6918966644110138
# Cost after iteration 4700: 0.6918966644108321
# Cost after iteration 4800: 0.6918966644106704
# Cost after iteration 4900: 0.6918966644105213
# Cost after iteration 5000: 0.6918966644103798
# Cost after iteration 5100: 0.6918966644102426
# Cost after iteration 5200: 0.6918966644101082
# Cost after iteration 5300: 0.6918966644099753
# Cost after iteration 5400: 0.6918966644098437
# Cost after iteration 5500: 0.6918966644097126
# Cost after iteration 5600: 0.6918966644095821
# Cost after iteration 5700: 0.6918966644094515
# Cost after iteration 5800: 0.6918966644093213
# Cost after iteration 5900: 0.691896664409191
# Cost after iteration 6000: 0.6918966644090606
# Cost after iteration 6100: 0.6918966644089307
# Cost after iteration 6200: 0.6918966644088007
# Cost after iteration 6300: 0.6918966644086705
# Cost after iteration 6400: 0.6918966644085404
# Cost after iteration 6500: 0.6918966644084102
# Cost after iteration 6600: 0.6918966644082801
# Cost after iteration 6700: 0.6918966644081501
# Cost after iteration 6800: 0.6918966644080201
# Cost after iteration 6900: 0.69189666440789
# Cost after iteration 7000: 0.6918966644077599
# Cost after iteration 7100: 0.6918966644076296
# Cost after iteration 7200: 0.6918966644074998
# Cost after iteration 7300: 0.6918966644073697
# Cost after iteration 7400: 0.6918966644072395
# Cost after iteration 7500: 0.6918966644071096
# Cost after iteration 7600: 0.6918966644069795
# Cost after iteration 7700: 0.6918966644068496
# Cost after iteration 7800: 0.6918966644067194
# Cost after iteration 7900: 0.6918966644065895
# Cost after iteration 8000: 0.6918966644064594
# Cost after iteration 8100: 0.6918966644063294
# Cost after iteration 8200: 0.6918966644061993
# Cost after iteration 8300: 0.6918966644060692
# Cost after iteration 8400: 0.6918966644059394
# Cost after iteration 8500: 0.6918966644058092
# Cost after iteration 8600: 0.6918966644056793
# Cost after iteration 8700: 0.6918966644055492
# Cost after iteration 8800: 0.6918966644054193
# Cost after iteration 8900: 0.6918966644052891
# Cost after iteration 9000: 0.6918966644051593
# Cost after iteration 9100: 0.6918966644050292
# Cost after iteration 9200: 0.6918966644048993
# Cost after iteration 9300: 0.6918966644047693
# Cost after iteration 9400: 0.6918966644046393
# Cost after iteration 9500: 0.6918966644045093
# Cost after iteration 9600: 0.6918966644043792
# Cost after iteration 9700: 0.6918966644042494
# Cost after iteration 9800: 0.6918966644041193
# Cost after iteration 9900: 0.6918966644039893
# Accuracy: 0.4
